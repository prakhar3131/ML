# %% [markdown]
# 1.What is Simple Linear Regression SLR? Explain its purpose.
#   Simple Linear Regression refers to the process of establishing the strength and charactestics of relationaship between one directly related independent and deendent variable.
# 2.What are the key assumptions of Simple Linear Regression?
#   Assumptions of SLR
#   1.X and Y should be linearly related with each other.
#   2.Normality, errors should fllow normal distribution.
#   3.Homoscadesticity,errors should depict constant variance across all levels.
#   4.Independence, rows should be independent of each other.
#   5.Variables should have least relation with each other.
# 3.Write the mathematical equation for a simple linear regression model and
# explain each term.
#   Mathematical equation for predicted value
#   y= mx + c, where m is slope and c is intercept.
#   If c is kept constant then every 1 unit increase in m y will change by x units.
# 4.Provide a real-world example where simple linear regression can be applied.
#    SLR can be used in redicting the cost of house in an area by taking the cost of other houses nearby as train and using it to predicts new hoouse cost.
# 5.What is the method of least squares in linear regression?
#   technique that determines the line of "best fit" by minimizing the sum of the squared differences  between the actual data points and the values predicted by the line.
# 6.What is Logistic Regression? How does it differ from Linear Regression?
#   Logistic regression is a machine learning algorithm used for binary classification, predicting the probabaility of outocme rather than continous value.
#
#   linear regression follows staright line regression to each other whereas
#   logistic regression foloows sigmoid function graph.
# 7.Name and briefly describe three common evaluation metrics for regression models.
#   Three common evaluation metrics for regression are
#   1.Mean Squared Error, mse is mean of squared differences between the actual and predicted values.
#   2.Accuracy rate- It is probability out of all predicted values hiw many are correctly predicted.
#   3.r_2 score- it refers to percent of change in y explained by x.
# 8.What is the purpose of the R-squared metric in regression analysis?
#   quantifies the proportion of total variation in the dependent variable explained by the model  making it easy to understand model goodness-of-fit.
# 10.How do you interpret the coefficients in a simple linear regression model?
#    EQAUTION Y=MX + C  If c is kept constant for every 1 unit increase in M the value of y will increase by x units and vice versa.

# %%
# 9.Write Python code to fit a simple linear regression model using scikit-learn
# and print the slope and intercept.
# Include your Python code and output in the code box below.

# The previous cells define X_train, Y_train, X_test, y_test, and create a LinearRegression model.
# The model was fitted in cell YZzPl8kkyloF after reshaping X_train.
# The predictions were made in cell A0EVVqjiyngk after reshaping X_test.

print(f"Slope (coefficient): {model.coef_[0]:.4f}")
print(f"Intercept: {model.intercept_:.4f}")

# %%
# ● X = [1, 2, 3, 4, 5]
# ● Y = [2.1, 4.3, 6.1, 7.9, 10.2]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.DataFrame({'X':[1,2,3,4,5],'Y':[2.1,4.3,6.1,7.9,10.2]})
df.head()

from sklearn.model_selection import train_test_split
X=df["X"]
y=df['Y']

X_train,X_test,Y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
X_train.shape
# Out:
# (3,)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model=model.fit(X_train.values.reshape(-1, 1),Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_186/2771233920.py in <cell line: 0>()
# ----> 1 model=model.fit(X_train,Y_train)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     599         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     600
# --> 601         X, y = validate_data(
#     602             self,
#     603             X,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
# ...

# %%
Y_pred=model.predict(X_test.values.reshape(-1, 1))

# %%
model.coef_
# Out:
# array([2.00384615])

# %%
model.intercept_
# Out:
# np.float64(0.05384615384615543)

# %%
#
